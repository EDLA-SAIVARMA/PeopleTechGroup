# %%
class Binarysearchtree:
    def __init__(self,data):
        self.data = data
        self.left = None
        self.right = None
    
    def addchild(self,data):
        if self.data == data:
            return
        if data < self.data:
            if self.left:
                self.left.addchild(data)
            else:
                self.left = Binarysearchtree(data)
        else:
            if self.right:
                self.right.addchild(data)
            else:
                self.right = Binarysearchtree(data)
                
    def search(self, val):
        if self.data == val:
            return True
        if val<self.data:
            if self.left:
                return self.left.search(val)
            else:
                return False
        else:
            if self.right:
                return self.right.search(val)
            else:
                return False
            
    def in_order_traversal(self):
        sorted = []
        
        if self.left:
            sorted = sorted + self.left.in_order_traversal()
        sorted.append(self.data)
        if self.right:
            sorted = sorted + self.right.in_order_traversal()
            
        return sorted
    
    def delete(self, val):
        if val < self.data:
            if self.left:
                self.left = self.left.delete(val)
        elif val > self.data:
            if self.right:
                self.right = self.right.delete(val)
        else:
            if self.left is None and self.right is None:
                return None
            elif self.left is None:
                return self.right
            elif self.right is None:
                return self.left

            pnt = self.right
            while pnt.left:
                pnt = pnt.left
            self.data = pnt.data
            self.right = self.right.delete(pnt.data)

        return self

    def find_max(self):
        print("self.right is:" ,self.right)
        if self.right is None:
            return self.data
        return self.right.find_max()

    def find_min(self):
        print("self.data inside findmin is:" ,self.data)
        print("self.left is:" ,self.left)
        if self.left is None:
            print("inside find_min is:" ,self.data)
            return self.data
        return self.left.find_min()
    
        
        

def build_tree(elements):
    root = Binarysearchtree(elements[0])
    
    for i in range(1,len(elements)):
        root.addchild(elements[i])
        
    return root

if __name__ == "__main__":

    elements = [17,4,1,9,20,23,18,34]
    build = build_tree(elements)
    
    s = build.search(20)

    print("traversal sorted is:" , build.in_order_traversal())
    build.delete(20)
    print("traversal sorted is:" , build.in_order_traversal())
# Out:
# traversal sorted is: [1, 4, 9, 17, 18, 20, 23, 34]
# traversal sorted is: [1, 4, 9, 17, 18, 23, 34]
